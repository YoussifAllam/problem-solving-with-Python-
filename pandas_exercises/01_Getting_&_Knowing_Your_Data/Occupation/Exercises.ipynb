# %% [markdown]
# # Ex3 - Getting and Knowing your Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user).

# %% [markdown]
# ### Step 3. Assign it to a variable called users and use the 'user_id' as index

# %%
users = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user')

# %%
id , age , grender , occupation , zip_code  = [],[],[],[],[]

for j in range(len(users)):
    i = str(users.iloc[i])
    i
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8992\3411784150.py in ?()
#       1 id , age , grender , occupation , zip_code  = [],[],[],[],[]
#       2
#       3 for j in range(len(users)):
# ----> 4     i = str(users.iloc[i])
#       5     i
#       6
#
# c:\Users\Youssif Allam\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py in ?(self, key)
#    1149             # we by definition only have the 0th axis
#    1150             axis = self.axis or 0
#    1151
#    1152             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1153             return self._getitem_axis(maybe_callable, axis=axis)
#
# c:\Users\Youssif Allam\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py in ?(self, key, axis)
#    1701             return self._getbool_axis(key, axis=axis)
#    1702
#    1703         # a list of integers
#    1704         elif is_list_like_indexer(key):
# -> 1705             return self._get_list_axis(key, axis=axis)
#    1706
#    1707         # a single integer
#    1708         else:
#
# c:\Users\Youssif Allam\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexing.py in ?(self, key, axis)
#    1673         `axis` can only be zero.
#    1674         """
#    1675         try:
#    1676             return self.obj._take_with_is_copy(key, axis=axis)
# -> 1677         except IndexError as err:
#    1678             # re-raise with different error message, e.g. test_getitem_ndarray_3d
#    1679             raise IndexError("positional indexers are out-of-bounds") from err
#
# c:\Users\Youssif Allam\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, indices, axis)
#    4084         For Series this does the same as the public take (it never sets `_is_copy`).
#    4085
#    4086         See the docstring of `take` for full explanation of the parameters.
#    4087         """
# -> 4088         result = self.take(indices=indices, axis=axis)
#    4089         # Maybe set copy if we didn't actually change the index.
#    4090         if self.ndim == 2 and not result._get_axis(axis).equals(self._get_axis(axis)):
#    4091             result._set_is_copy(self)
#
# c:\Users\Youssif Allam\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py in ?(self, indices, axis, **kwargs)
#    4037
#    4038         nv.validate_take((), kwargs)
#    4039
#    4040         if not isinstance(indices, slice):
# -> 4041             indices = np.asarray(indices, dtype=np.intp)
#    4042             if (
#    4043                 axis == 0
#    4044                 and indices.ndim == 1
#
# ValueError: invalid literal for int() with base 10: 'user_id|age|gender|occupation|zip_code'

# %%
id
# Out:
# ['user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code',
#  'user_id|age|gender|occupation|zip_code']

# %% [markdown]
# ### Step 4. See the first 25 entries

# %%
users.head(25)
# Out:
#    user_id|age|gender|occupation|zip_code
# 0                 1|24|M|technician|85711
# 1                      2|53|F|other|94043
# 2                     3|23|M|writer|32067
# 3                 4|24|M|technician|43537
# 4                      5|33|F|other|15213
# 5                  6|42|M|executive|98101
# 6              7|57|M|administrator|91344
# 7              8|36|M|administrator|05201
# 8                    9|29|M|student|01002
# 9                    10|53|M|lawyer|90703
# 10                    11|39|F|other|30329
# 11                    12|28|F|other|06405
# 12                 13|47|M|educator|29206
# 13                14|45|M|scientist|55106
# 14                 15|49|F|educator|97301
# 15            16|21|M|entertainment|10309
# 16               17|30|M|programmer|06355
# 17                    18|35|F|other|37212
# 18                19|40|M|librarian|02138
# 19                20|42|F|homemaker|95660
# 20                   21|26|M|writer|30068
# 21                   22|25|M|writer|40206
# 22                   23|30|F|artist|48197
# 23                   24|21|F|artist|94533
# 24                 25|39|M|engineer|55107

# %% [markdown]
# ### Step 5. See the last 10 entries

# %%
users.tail(10)
# Out:
#     user_id|age|gender|occupation|zip_code
# 933                934|61|M|engineer|22902
# 934                  935|42|M|doctor|66221
# 935                   936|24|M|other|32789
# 936                937|48|M|educator|98072
# 937              938|38|F|technician|55038
# 938                 939|26|F|student|33319
# 939           940|32|M|administrator|02215
# 940                 941|20|M|student|97229
# 941               942|48|F|librarian|78209
# 942                 943|22|M|student|77841

# %% [markdown]
# ### Step 6. What is the number of observations in the dataset?

# %%
users.shape
# Out:
# (943, 1)

# %% [markdown]
# ### Step 7. What is the number of columns in the dataset?

# %%
len(users.columns)
# Out:
# 1

# %% [markdown]
# ### Step 8. Print the name of all the columns.

# %%
users.columns
# Out:
# Index(['user_id|age|gender|occupation|zip_code'], dtype='object')

# %% [markdown]
# ### Step 9. How is the dataset indexed?

# %% [markdown]
# ### Step 10. What is the data type of each column?

# %% [markdown]
# ### Step 11. Print only the occupation column

# %% [markdown]
# ### Step 12. How many different occupations are in this dataset?

# %% [markdown]
# ### Step 13. What is the most frequent occupation?

# %% [markdown]
# ### Step 14. Summarize the DataFrame.

# %% [markdown]
# ### Step 15. Summarize all the columns

# %% [markdown]
# ### Step 16. Summarize only the occupation column

# %% [markdown]
# ### Step 17. What is the mean age of users?

# %% [markdown]
# ### Step 18. What is the age with least occurrence?
